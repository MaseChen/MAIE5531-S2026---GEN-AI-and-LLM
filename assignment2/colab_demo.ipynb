# %% [markdown]
# ###  Mount Google Drive

# %%
import os

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

! mkdir -p /content/drive/MyDrive/MAIE5531-Homework2
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Clone Codebase

# %%
! mkdir -p /content/drive/MyDrive/MAIE5531-Homework2
! cd /content/drive/MyDrive/MAIE5531-Homework2 && git clone https://github.com/MaseChen/MAIE5531-S2026---GEN-AI-and-LLM
# Out:
# Cloning into 'MAIE5531-S2026---GEN-AI-and-LLM'...
# remote: Enumerating objects: 126, done.
# remote: Counting objects: 100% (126/126), done.
# remote: Compressing objects: 100% (112/112), done.
# remote: Total 126 (delta 53), reused 24 (delta 12), pack-reused 0 (from 0)
# Receiving objects: 100% (126/126), 306.36 KiB | 1.83 MiB/s, done.
# Resolving deltas: 100% (53/53), done.

# %% [markdown]
# ### Download Dataset

# %%
! cd /content/drive/MyDrive/MAIE5531-Homework2/MAIE5531-S2026---GEN-AI-and-LLM/assignment2/ && bash download_data.sh
# Out:
# Starting data downloads...
# ...
# curl: option --no-clobber: is unknown
# curl: try 'curl --help' or 'curl --manual' for more information
# gzip: data.warc.gz: No such file or directory
# curl: option --no-clobber: is unknown
# curl: try 'curl --help' or 'curl --manual' for more information
# gzip: data.wet.gz: No such file or directory
# curl: option --no-clobber: is unknown
# curl: try 'curl --help' or 'curl --manual' for more information
# gzip: data.wat.gz: No such file or directory
# Common Crawl data download completed.
# ...
# --2026-04-22 07:02:43--  https://osf.io/download/ywea7/
# Resolving osf.io (osf.io)... 35.190.84.173
# Connecting to osf.io (osf.io)|35.190.84.173|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://files.osf.io/v1/resources/ryjfm/providers/osfstorage/6819fdbfbecda878d4c61566 [following]
# --2026-04-22 07:02:43--  https://files.osf.io/v1/resources/ryjfm/providers/osfstorage/6819fdbfbecda878d4c61566
# ...

# %%
! cd /content/drive/MyDrive/MAIE5531-Homework2/MAIE5531-S2026---GEN-AI-and-LLM/assignment2/llama_training

# %%
! bash /content/drive/MyDrive/MAIE5531-Homework2/MAIE5531-S2026---GEN-AI-and-LLM/assignment2/llama_training/setup.sh
# Out:
# /content/drive/MyDrive/MAIE5531-Homework2/MAIE5531-S2026---GEN-AI-and-LLM/assignment2/llama_training/setup.sh: line 3: conda: command not found
# /content/drive/MyDrive/MAIE5531-Homework2/MAIE5531-S2026---GEN-AI-and-LLM/assignment2/llama_training/setup.sh: line 4: conda: command not found
# /content/drive/MyDrive/MAIE5531-Homework2/MAIE5531-S2026---GEN-AI-and-LLM/assignment2/llama_training/setup.sh: line 6: cd: ../data_preprocess: No such file or directory
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# /content/drive/MyDrive/MAIE5531-Homework2/MAIE5531-S2026---GEN-AI-and-LLM/assignment2/llama_training/setup.sh: line 8: cd: ../llama_training: No such file or directory
# Looking in indexes: https://download.pytorch.org/whl/cu124
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 70.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 68.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Start The Training

# %%
! cd /content/drive/MyDrive/MAIE5531-Homework2/MAIE5531-S2026---GEN-AI-and-LLM/assignment2/llama_training && bash run_babylm.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# train-0:  68% 997/1473 [4:18:59<1:42:43, 12.95s/it, step_tok_loss=2.5747, avg_tok_loss=3.2614]
# train-0:  68% 997/1473 [4:18:59<1:42:43, 12.95s/it, step_tok_loss=2.5319, avg_tok_loss=3.2606]
# train-0:  68% 998/1473 [4:19:12<1:42:33, 12.95s/it, step_tok_loss=2.5319, avg_tok_loss=3.2606]
# train-0:  68% 998/1473 [4:19:12<1:42:33, 12.95s/it, step_tok_loss=2.4513, avg_tok_loss=3.2598]
# train-0:  68% 999/1473 [4:19:25<1:42:21, 12.96s/it, step_tok_loss=2.4513, avg_tok_loss=3.2598]
# train-0:  68% 999/1473 [4:19:25<1:42:21, 12.96s/it, step_tok_loss=2.4889, avg_tok_loss=3.2591]
# train-0:  68% 1000/1473 [4:19:38<1:42:06, 12.95s/it, step_tok_loss=2.4889, avg_tok_loss=3.2591]
# train-0:  68% 1000/1473 [4:19:38<1:42:06, 12.95s/it, step_tok_loss=2.5438, avg_tok_loss=3.2583]
#
# val:   0% 0/2408 [00:00<?, ?it/s]
#
# val:   0% 1/2408 [00:00<11:08,  3.60it/s]
#
# val:   0% 2/2408 [00:00<11:02,  3.63it/s]
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !find /content/drive/MyDrive/MAIE5531-Homework2/llama_training -type f -printf "%TY-%Tm-%Td %TH:%TM %p\n" | sort | tail -30
# Out:
# find: ‘/content/drive/MyDrive/MAIE5531-Homework2/llama_training’: No such file or directory
